# %% [markdown]
# Figure out how to serialize the compute so it can run with client

# %%
import xarray as xr
import numpy as np
import dask as da
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from dask.distributed import Client,progress
from dask.diagnostics import ProgressBar
import time

# %%
from dask.distributed import LocalCluster
cluster = LocalCluster()          # Fully-featured local Dask cluster
client = cluster.get_client()

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:58006' processes=6 threads=24, memory=63.25 GiB>

# %%
reanalysis = xr.open_zarr(
    'gs://gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3',
    chunks={"time": 48},
    storage_options=dict(token='anon'),
)
# Out:
# c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,

# %%
#client = Client()
#client
# Out:
# <Client: 'tcp://127.0.0.1:57602' processes=6 threads=24, memory=63.25 GiB>

# %%
def roll_longitude(ds):
    return ds.assign_coords(longitude=(((ds.longitude + 180) % 360) - 180)).sortby('longitude')

# %%
dx = reanalysis.sel(time=slice('2020-01-01','2020-01-05'))
dx  = roll_longitude(dx)
dx = dx.sel(latitude = slice(90,20),longitude=slice(-150,-40))

# %%
dx_array = dx['2m_temperature']

# %%
data = dx_array#.mean(dim="time")

# %%
data
# Out:
# <xarray.DataArray '2m_temperature' (time: 120, latitude: 281, longitude: 441)>
# dask.array<getitem, shape=(120, 281, 441), dtype=float32, chunksize=(48, 281, 441), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... 20.5 20.25 20.0
#   * longitude  (longitude) float32 -150.0 -149.8 -149.5 ... -40.5 -40.25 -40.0
#   * time       (time) datetime64[ns] 2020-01-01 ... 2020-01-05T23:00:00
# Attributes:
#     long_name:   2 metre temperature
#     short_name:  t2m
#     units:       K

# %%
# %%time
with ProgressBar():
    teste = data.persist()
# Out:
# [########################################] | 100% Completed | 3.27 ss
# CPU times: total: 1.44 s
# Wall time: 3.29 s

# %%
#!Dont run

teste.to_netcdf('ERA5/arco-era5/data/temp.nc')

# %%
#!Dont run
teste2 = data.mean(dim="time")
# %%time
with ProgressBar():
    teste = teste2.compute()

#compute: https://distributed.dask.org/en/stable/manage-computation.html#:~:text=You%20can%20turn%20any%20dask%20collection%20into%20a,collection%20to%20a%20concrete%20value%20in%20local%20memory.
#diagnostic https://dask.pydata.org/en/latest/diagnostics-distributed.html
#scheduler: https://docs.dask.org/en/stable/scheduler-overview.html?highlight=scheduler#configuring-schedulers
#Dask delayed: https://examples.dask.org/applications/embarrassingly-parallel.html

# %%
from dask.distributed import performance_report,get_task_stream
teste2 = data.mean(dim="time")

# %%
from distributed.protocol import serialize

# %%
serialize(teste2)
# Out:
# ({'serializer': 'pickle', 'writeable': (True, True, True, True, True, True)},
0cdependencies\x94}\x94(\x8cEoriginal-open_dataset-2m_temperature-0b00311fbbe1b229bc2a1997debba0b1\x94\x8f\x94\x8c<open_dataset-2m_temperature-0b00311fbbe1b229bc2a1997debba0b1\x94\x8f\x94(h\x81\x90\x8c(getitem-08c056c4ac0605389ed37107056ead78\x94\x8f\x94(h\x83\x90\x8c(getitem-fd4ba96433151f251625637ef7178518\x94\x8f\x94(h\x85\x90\x8c(getitem-cd4b9de7e46294471f1d68ba1091fd2e\x94\x8f\x94(h\x87\x90\x8c+mean_chunk-9b4b201758e9d02b26b0f351a7715a1e\x94\x8f\x94(h\x89\x90\x8c5mean_combine-partial-f5dd8f94f1f0aec3af4532d797b3cc67\x94\x8f\x94(h\x8b\x90\x8c5mean_combine-partial-296913736cdf8da70e1f2620d7795286\x94\x8f\x94(h\x8d\x90\x8c5mean_combine-partial-c712e38baf7392aaf0ba8462f8e49950\x94\x8f\x94(h\x8f\x90\x8c3mean_agg-aggregate-ffcc2eb18a1c7268fb81098a4f1446af\x94\x8f\x94(h\x91\x90u\x8c\x10key_dependencies\x94}\x94\x8c\x06layers\x94}\x94(h\x81hz\x8c\x11MaterializedLayer\x94\x93\x94)\x81\x94}\x94(\x8c\x0bannotations\x94N\x8c\x16collection_annotations\x94N\x8c\x07mapping\x94}\x94h\x81h\x10\x8c!ImplicitToExplicitIndexingAdapter\x94\x93\x94)\x81\x94N}\x94(h\x15h\x10\x8c\x10CopyOnWriteArray\x94\x93\x94)\x81\x94N}\x94(h\x15h\x10\x8c\x12LazilyIndexedArray\x94\x93\x94)\x81\x94N}\x94(h\x15\x8c\x14xarray.backends.zarr\x94\x8c\x10ZarrArrayWrapper\x94\x93\x94)\x81\x94N}\x94(\x8c\tdatastore\x94h\xad\x8c\tZarrStore\x94\x93\x94)\x81\x94N}\x94(\x8c\nzarr_group\x94\x8c\x0ezarr.hierarchy\x94\x8c\x05Group\x94\x93\x94)\x81\x94}\x94(\x8c\x05store\x94\x8c\x0czarr.storage\x94\x8c\x19ConsolidatedMetadataStore\x94\x93\x94)\x81\x94}\x94(h\xbdh\xbe\x8c\x07FSStore\x94\x93\x94)\x81\x94}\x94(\x8c\x03map\x94\x8c\x0efsspec.mapping\x94\x8c\x05FSMap\x94\x93\x94(\x8c?gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3\x94\x8c\x0bfsspec.spec\x94\x8c\rmake_instance\x94\x93\x94\x8c\ngcsfs.core\x94\x8c\rGCSFileSystem\x94\x93\x94)}\x94\x8c\x05token\x94\x8c\x04anon\x94s\x87\x9 ...
#   <memory at 0x000001F7BE1687C0>,
#   <memory at 0x000001F7BE169180>,
#   <memory at 0x000001F7BE15FB00>,
#   <memory at 0x000001F7BE1696C0>,
#   <memory at 0x000001F7BE168F40>,
#   <memory at 0x000001F7BE85FC60>])

# %%
with get_task_stream(plot='save', filename="task-stream.html") as ts:
    data.mean(dim='time').compute()
# Out:
# 2024-09-26 21:34:08,033 - distributed.protocol.core - CRITICAL - Failed to Serialize
# Traceback (most recent call last):
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2024-09-26 21:34:08,036 - distributed.comm.utils - ERROR - 0-dim memory has no length
# Traceback (most recent call last):
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2024-09-26 21:34:08,038 - distributed.batched - ERROR - Error in batched write
# Traceback (most recent call last):
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\batched.py", line 115, in _background_send
#     nbytes = yield coro
#              ^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\tornado\gen.py", line 766, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\comm\tcp.py", line 264, in write
#     frames = await to_frames(
#              ^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\comm\utils.py", line 50, in to_frames
#     return _to_frames()
#            ^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# ---------------------------------------------------------------------------
# FutureCancelledError                      Traceback (most recent call last)
# Cell In[20], line 2
#       1 with get_task_stream(plot='save', filename="task-stream.html") as ts:
# ----> 2     data.mean(dim='time').compute()
#
# File c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\xarray\core\dataarray.py:1102, in DataArray.compute(self, **kwargs)
#    1083 """Manually trigger loading of this array's data from disk or a
#    1084 remote source into memory and return a new array. The original is
#    1085 left unaltered.
#    (...)
#    1099 dask.compute
#    1100 """
#    1101 new = self.copy(deep=False)
# -> 1102 return new.load(**kwargs)
#
# File c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\xarray\core\dataarray.py:1076, in DataArray.load(self, **kwargs)
#    1058 def load(self: T_DataArray, **kwargs) -> T_DataArray:
#    1059     """Manually trigger loading of this array's data from disk or a
#    1060     remote source into memory and return this array.
#    1061
#    (...)
#    1074     dask.compute
#    1075     """
# -> 1076     ds = self._to_temp_dataset().load(**kwargs)
#    1077     new = self._from_temp_dataset(ds)
#    1078     self._variable = new._variable
#
# File c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\xarray\core\dataset.py:792, in Dataset.load(self, **kwargs)
#     789 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     791 # evaluate all the chunked arrays simultaneously
# --> 792 evaluated_data = chunkmanager.compute(*lazy_data.values(), **kwargs)
#     794 for k, data in zip(lazy_data, evaluated_data):
#     795     self.variables[k].data = data
#
# File c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\xarray\core\daskmanager.py:70, in DaskManager.compute(self, *data, **kwargs)
#      67 def compute(self, *data: DaskArray, **kwargs) -> tuple[np.ndarray, ...]:
#      68     from dask.array import compute
# ---> 70     return compute(*data, **kwargs)
#
# File c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\dask\base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\client.py:2417, in Client._gather(self, futures, errors, direct, local_worker)
#    2415     exception = st.exception
#    2416     traceback = st.traceback
# -> 2417     raise exception.with_traceback(traceback)
#    2418 if errors == "skip":
#    2419     bad_keys.add(key)
#
# FutureCancelledError: ('mean_agg-aggregate-ffcc2eb18a1c7268fb81098a4f1446af', 0, 0) cancelled for reason: scheduler-connection-lost.
# Client lost the connection to the scheduler. Please check your connection and re-run your work.

# %%
with performance_report(filename="temp/dask-report.html"):
    teste = teste2.compute()
# Out:
# 2024-09-26 21:29:14,377 - distributed.protocol.core - CRITICAL - Failed to Serialize
# Traceback (most recent call last):
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2024-09-26 21:29:14,383 - distributed.comm.utils - ERROR - 0-dim memory has no length
# Traceback (most recent call last):
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2024-09-26 21:29:14,387 - distributed.batched - ERROR - Error in batched write
# Traceback (most recent call last):
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\batched.py", line 115, in _background_send
#     nbytes = yield coro
#              ^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\tornado\gen.py", line 766, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\comm\tcp.py", line 264, in write
#     frames = await to_frames(
#              ^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\comm\utils.py", line 50, in to_frames
#     return _to_frames()
#            ^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# ---------------------------------------------------------------------------
# FutureCancelledError                      Traceback (most recent call last)
# Cell In[13], line 2
#       1 with performance_report(filename="temp/dask-report.html"):
# ----> 2     teste = teste2.compute()
#
# File c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\xarray\core\dataarray.py:1102, in DataArray.compute(self, **kwargs)
#    1083 """Manually trigger loading of this array's data from disk or a
#    1084 remote source into memory and return a new array. The original is
#    1085 left unaltered.
#    (...)
#    1099 dask.compute
#    1100 """
#    1101 new = self.copy(deep=False)
# -> 1102 return new.load(**kwargs)
#
# File c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\xarray\core\dataarray.py:1076, in DataArray.load(self, **kwargs)
#    1058 def load(self: T_DataArray, **kwargs) -> T_DataArray:
#    1059     """Manually trigger loading of this array's data from disk or a
#    1060     remote source into memory and return this array.
#    1061
#    (...)
#    1074     dask.compute
#    1075     """
# -> 1076     ds = self._to_temp_dataset().load(**kwargs)
#    1077     new = self._from_temp_dataset(ds)
#    1078     self._variable = new._variable
#
# File c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\xarray\core\dataset.py:792, in Dataset.load(self, **kwargs)
#     789 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     791 # evaluate all the chunked arrays simultaneously
# --> 792 evaluated_data = chunkmanager.compute(*lazy_data.values(), **kwargs)
#     794 for k, data in zip(lazy_data, evaluated_data):
#     795     self.variables[k].data = data
#
# File c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\xarray\core\daskmanager.py:70, in DaskManager.compute(self, *data, **kwargs)
#      67 def compute(self, *data: DaskArray, **kwargs) -> tuple[np.ndarray, ...]:
#      68     from dask.array import compute
# ---> 70     return compute(*data, **kwargs)
#
# File c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\dask\base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File c:\Users\ls2236\AppData\Local\anaconda3\Lib\site-packages\distributed\client.py:2417, in Client._gather(self, futures, errors, direct, local_worker)
#    2415     exception = st.exception
#    2416     traceback = st.traceback
# -> 2417     raise exception.with_traceback(traceback)
#    2418 if errors == "skip":
#    2419     bad_keys.add(key)
#
# FutureCancelledError: ('mean_agg-aggregate-ffcc2eb18a1c7268fb81098a4f1446af', 0, 0) cancelled for reason: scheduler-connection-lost.
# Client lost the connection to the scheduler. Please check your connection and re-run your work.

# %%
#check file
file_name = "ERA5/arco-era5/data/2m_temperature_19980101_19990101.nc"
ds =  xr.open_mfdataset(file_name, chunks={'time': 48})

# %%
ds.isel(latitude=-50)["2m_temperature"].plot()
